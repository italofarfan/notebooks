# %% [markdown]
# # Impacto del Big Data en nuestras vidas
#
# Algeciras, 30 de abril de 2015
#
# \#bbESTR

# %% [markdown]
# ## ¿Quién soy?
#
# * Italo Farfán Vera - [@italoFarve](https://twitter.com/italoFarVe)
# * Msc. Inteligencia Artificial (UPM)
# * Bsc. Ingeniería Electrónica (UTP)
# * Emprendedor (Viz Analytics)

# %% [markdown]
# ## Big Data

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('FJrRhEvP3EE')
# Fuente: https://www.youtube.com/watch?v=FJrRhEvP3EE
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/FJrRhEvP3EE"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Universo digital

# %%
from IPython.display import Image
Image(filename='figs/bigdata-g.jpg')
# Más info: http://recode.net/2014/01/10/stuffed-why-data-storage-is-hot-again-really/

# %%
from IPython.display import Image
Image(filename='figs/zettabyte.jpg' width=800)

# %% [markdown]
# ![Imagen](figs/bigdata-g.jpg)

# %% [markdown]
# ![Imagen](figs/zettabyte.jpg)
